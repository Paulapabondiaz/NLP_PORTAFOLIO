# %% [markdown]
# <img src='https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQ-VfNtOyJbsaxu43Kztf_cv1mgBG6ZIQZEVw&usqp=CAU'>
#
# # Procesamiento de Lenguaje Natural
#
# ## Taller #9: Modelado de temas
# `Fecha de entrega: Mayo 6, 2021. (Antes del inicio de la próxima clase).`
#
# `Modo de entrega: Subir link de GitHub al aula virtual.`

# %%
import re
import pandas as pd 
from pprint import pprint

from nltk.corpus import stopwords
stopwords = stopwords.words('spanish')

import pyLDAvis.gensim_models
from gensim.models import LdaModel
from gensim.corpora import Dictionary

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# C:\Users\paula\Anaconda3\lib\site-packages\scipy\sparse\sparsetools.py:21: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()
# C:\Users\paula\AppData\Roaming\Python\Python38\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
# Cargar datos
path = "C:/Users/paula/OneDrive/Escritorio/KONRAD_LORENZ/SEMESTRE_II/NLP/reviews_vidjew_es.csv"
data = pd.read_csv(path)
data.head()
# Out:
#     review_id          product_id          reviewer_id  stars  \
# 0  es_0825565  product_es_0370490  reviewer_es_0174781      3
# 1  es_0227934  product_es_0354224  reviewer_es_0411613      3
# 2  es_0468601  product_es_0665460  reviewer_es_0348315      1
# 3  es_0814494  product_es_0692692  reviewer_es_0951508      5
# 4  es_0206329  product_es_0728826  reviewer_es_0493255      4
#
#                                          review_body            review_title  \
# 0         Buen. Buena calidad, y buena presentación.                Contenta
# 1  Un producto a perfecto, para salir de casa con...            Versatilidad
# 2  No funciona con Nintendo Switch. No hay forma ...      Decepción absoluta
# 3  Recomendado, los utilizo para pc y no me dan n...  Auriculares Pecham ps4
# 4  El cable funciona bien podria ser un poco mas ...                Perfecto
#
#   language product_category
# 0       es          jewelry
# 1       es      video_games
# 2       es      video_games
# ...

# %% [markdown]
# ###  `[12 pts]` Punto 1: Hacer pre-procesamiento del texto

# %%
import re 

from nltk.corpus import stopwords
stopwords = stopwords.words('spanish')


def pre_procesado(texto):
    texto = texto.lower()
    texto = re.sub(r"[\W\d]+", " ", texto)
    texto = [palabra for palabra in texto.split() if palabra not in stopwords]
    return texto 

data['PP'] = data['review_body'].apply(lambda texto: pre_procesado(texto))

data.head()
# Out:
#     review_id          product_id          reviewer_id  stars  \
# 0  es_0825565  product_es_0370490  reviewer_es_0174781      3
# 1  es_0227934  product_es_0354224  reviewer_es_0411613      3
# 2  es_0468601  product_es_0665460  reviewer_es_0348315      1
# 3  es_0814494  product_es_0692692  reviewer_es_0951508      5
# 4  es_0206329  product_es_0728826  reviewer_es_0493255      4
#
#                                          review_body            review_title  \
# 0         Buen. Buena calidad, y buena presentación.                Contenta
# 1  Un producto a perfecto, para salir de casa con...            Versatilidad
# 2  No funciona con Nintendo Switch. No hay forma ...      Decepción absoluta
# 3  Recomendado, los utilizo para pc y no me dan n...  Auriculares Pecham ps4
# 4  El cable funciona bien podria ser un poco mas ...                Perfecto
#
#   language product_category                                                 PP
# ...

# %% [markdown]
# ###  `[10 pts]` Punto 2: Modelo de LDA

# %%
import pyLDAvis.gensim_models
from gensim.models import LdaModel 
from gensim.corpora import Dictionary
from pprint import pprint

# %%
# Crear una represantación de los documentos en forma de diccionario
dictionary = Dictionary(data['PP'].values)

# Filtrar palabras muy frecuentes o infrecuentes
dictionary.filter_extremes(no_below=5, no_above=0.5) 

# Corpus
corpus = [dictionary.doc2bow(text) for text in data['PP'].values]

# Entrenar el modelo
model = LdaModel(corpus = corpus, id2word = dictionary, num_topics = 5, passes=50)

# %%
model.print_topics(num_words=15)
# Out:
# [(0,
#   '0.037*"día" + 0.024*"bien" + 0.020*"llegado" + 0.020*"después" + 0.018*"tan" + 0.018*"pedido" + 0.015*"amazon" + 0.014*"meses" + 0.012*"llegar" + 0.012*"juego" + 0.012*"entregado" + 0.011*"cierre" + 0.011*"precio" + 0.011*"llegó" + 0.011*"recibido"'),
#  (1,
#   '0.032*"bien" + 0.030*"juego" + 0.023*"perfecto" + 0.022*"si" + 0.019*"caja" + 0.019*"producto" + 0.018*"mas" + 0.014*"llego" + 0.012*"mejor" + 0.012*"juegos" + 0.011*"problema" + 0.011*"funciona" + 0.011*"puedo" + 0.009*"mal" + 0.009*"aunque"'),
#  (2,
#   '0.074*"calidad" + 0.047*"precio" + 0.040*"buena" + 0.027*"buen" + 0.026*"pulsera" + 0.024*"producto" + 0.018*"bien" + 0.016*"bonita" + 0.015*"bastante" + 0.014*"cadena" + 0.014*"mala" + 0.014*"regalo" + 0.013*"puede" + 0.011*"compra" + 0.010*"gracias"'),
#  (3,
# ...

# %% [markdown]
# ###  `[25 pts]` Punto 3: Visualización de LDA

# %%
lda_display = pyLDAvis.gensim_models.prepare(model, corpus, dictionary, sort_topics=True)
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1322411499210486083453706962"></div>
# <script type="text/javascript">
#
# ...

# %%
def get_doc_top_n(text_processed, n):
    d = dictionary.doc2bow(text_processed)
    topics = dict(model.get_document_topics(d))
    try:
        return topics[n]
    except:
        return None

# %%
for t in range(0,4):
    top_name = f"topic_{t}"
    data[top_name] = data['PP'].apply(lambda doc: get_doc_top_n(doc, t))

# %%
data
# Out:
#       review_id          product_id          reviewer_id  stars  \
# 0    es_0825565  product_es_0370490  reviewer_es_0174781      3
# 1    es_0227934  product_es_0354224  reviewer_es_0411613      3
# 2    es_0468601  product_es_0665460  reviewer_es_0348315      1
# 3    es_0814494  product_es_0692692  reviewer_es_0951508      5
# 4    es_0206329  product_es_0728826  reviewer_es_0493255      4
# ..          ...                 ...                  ...    ...
# 995  es_0427672  product_es_0899883  reviewer_es_0474735      2
# 996  es_0059540  product_es_0702564  reviewer_es_0754753      3
# 997  es_0303349  product_es_0678671  reviewer_es_0172313      5
# 998  es_0659961  product_es_0294943  reviewer_es_0554554      4
# 999  es_0441429  product_es_0478207  reviewer_es_0691110      2
#
#                                            review_body  \
# 0           Buen. Buena calidad, y buena presentación.
# 1    Un producto a perfecto, para salir de casa con...
# ...

# %% [markdown]
# ###  `[3 pts]` Preguntas
#
# - ¿Qué conclusiones puede sacar de los resultados de los últimos tres talleres, usando diferentes modelos pero los mismos datos?

# %%
#LDA
d = dictionary.doc2bow(["Necesitas", "juego", "inicial", "para", "eso"])
topics = [(cluster[0]+1, cluster[1]) for cluster in model.get_document_topics(d)]
topics
# Out:
# [(1, 0.101468384),
#  (2, 0.5947961),
#  (3, 0.10000158),
#  (4, 0.10227966),
#  (5, 0.101454236)]

# %%
# indica qie corresponde al cluster 2 "bonito" "bien" "bonitos"

# %%
#LDA
d = dictionary.doc2bow(["Preciosos", "estos", "aretes", "buena", "calidad"])
topics = [(cluster[0]+1, cluster[1]) for cluster in model.get_document_topics(d)]
topics
# Out:
# [(1, 0.06678633),
#  (2, 0.06666692),
#  (3, 0.7328097),
#  (4, 0.06696081),
#  (5, 0.066776246)]

# %%
# indica qie corresponde al cluster 3 "calidad" "precio" "buena" "buen"

# %%
#Regresion Logistica
test1 = ["Necesitas el juego inicial para eso", "Preciosos estos aretes, buena calidad"]
test1_trans = tfidf_vect.transform(test1)
logreg.predict(test1_trans)


array(['video_games', 'jewelry'], dtype=object)

# %%
#K-Means
nuevo = ["Necesitas el juego inicial para eso", "Preciosos estos aretes, buena calidad"]
nuevo_trans = tfidf_vect.transform(nuevo)
[clusters[i] for i in model.predict(nuevo_trans)]

['5', '4'] -> 
Cluster # 4
Tiene 101 registros (10.10% de los datos)
#tiene como mayor representacion los documentos que indican la inconformidad del cliente con respecto al producto que pidieron (2 doc de joyas y 1 de viedojuegos)

Cluster # 5
Tiene 87 registros (8.70% de los datos)
#tiene como mayor representacion los documentos que describen al producto como "muy bonito" (2 doc de joyas y 1 de viedojuegos)

# %%
# haciendo la comparacion entre 3 talleres considero que K-means y LDA son los mas parecidos, dado que segmentan los documentos de acuerdo a su contenido, 
#me parece que k-means es la herramienta mas efeciva, dado que nos indica el numero de clusters idoneos y nos pronostica con textos completos sin necesitdad
#de discriminar solo por palabras.
